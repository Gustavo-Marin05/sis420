# %%
import numpy as np
import pandas as pd

# Librerias para graficación (trazado de gráficos)
from matplotlib import pyplot

# %%
data = pd.read_csv('./Breast_cancer_dataset.csv',delimiter=',')



#borrar las columnas
data = data.drop(columns=['Unnamed: 32','id'])
#renombrara valores
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})

X_w = data.iloc[:,1]
y_w = data.iloc[:, 4] 

#convertir a array

X = X_w.to_numpy()
y = y_w.to_numpy() 


m = y.size 

data.head()

#print(data)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
print(X)
# Out:
# [17.99  20.57  19.69  11.42  20.29  12.45  18.25  13.71  13.    12.46
#  16.02  15.78  19.17  15.85  13.73  14.54  14.68  16.13  19.81  13.54
#  13.08   9.504 15.34  21.16  16.65  17.14  14.58  18.61  15.3   17.57
#  18.63  11.84  17.02  19.27  16.13  16.74  14.25  13.03  14.99  13.48
#  13.44  10.95  19.07  13.28  13.17  18.65   8.196 13.17  12.05  13.49
#  11.76  13.64  11.94  18.22  15.1   11.52  19.21  14.71  13.05   8.618
#  10.17   8.598 14.25   9.173 12.68  14.78   9.465 11.31   9.029 12.78
#  18.94   8.888 17.2   13.8   12.31  16.07  13.53  18.05  20.18  12.86
#  11.45  13.34  25.22  19.1   12.    18.46  14.48  19.02  12.36  14.64
#  14.62  15.37  13.27  13.45  15.06  20.26  12.18   9.787 11.6   14.42
#  13.61   6.981 12.18   9.876 10.49  13.11  11.64  12.36  22.27  11.34
#   9.777 12.63  14.26  10.51   8.726 11.93   8.95  14.87  15.78  17.95
#  11.41  18.66  24.25  14.5   13.37  13.85  13.61  19.    15.1   19.79
# ...

# %%
print(y)
# Out:
# [1001.  1326.  1203.   386.1 1297.   477.1 1040.   577.9  519.8  475.9
#   797.8  781.  1123.   782.7  578.3  658.8  684.5  798.8 1260.   566.3
#   520.   273.9  704.4 1404.   904.6  912.7  644.8 1094.   732.4  955.1
#  1088.   440.6  899.3 1162.   807.2  869.5  633.   523.8  698.8  559.2
#   563.   371.1 1104.   545.2  531.5 1076.   201.9  534.6  449.3  561.
#   427.9  571.8  437.6 1033.   712.8  409.  1152.   656.9  527.2  224.5
#   311.9  221.8  645.7  260.9  499.   668.3  269.4  394.1  250.5  502.5
#  1130.   244.   929.4  584.1  470.9  817.7  559.2 1006.  1245.   506.3
#   401.5  520.  1878.  1132.   443.3 1075.   648.2 1076.   466.1  651.9
#   662.7  728.2  551.7  555.1  705.6 1264.   451.1  294.5  412.6  642.5
#   582.7  143.5  458.7  298.3  336.1  530.2  412.5  466.7 1509.   396.5
#   290.2  480.4  629.9  334.2  230.9  438.6  245.2  682.5  782.6  982.
#   403.3 1077.  1761.   640.7  553.5  588.7  572.6 1138.   674.5 1192.
# ...

# %%
print(X.size)
# Out:
# 569

# %%
def plotData(x, y):
    fig = pyplot.figure()  # abre una nueva figura

    pyplot.plot(x, y, 'ro', ms=10, mec='k')
    pyplot.ylabel('Área promedio')
    pyplot.xlabel('Radio promedio')

# %%
plotData(X, y)

# %%
#agregamos columna de 1
X = np.stack([np.ones(m), X], axis=1)

print(X)
# Out:
# [[ 1.   17.99]
#  [ 1.   20.57]
#  [ 1.   19.69]
#  ...
#  [ 1.   16.6 ]
#  [ 1.   20.6 ]
#  [ 1.    7.76]]

# %%
def calcularCosto(X, y, theta):
   
    m = y.size 
    J = 0
    J = (1/(2 * m)) * np.sum(np.square(np.dot(X, theta) - y))
    return J

# %%
J = calcularCosto(X, y, theta=np.array([0.0, 0.0]))
print('Con theta = [0, 0] \n Costo calculado = %.2f' % J)
# print('Valor de costo esperado (aproximadamente) 32.07\n')

# pruebas adicionales de la función de costes
J = calcularCosto(X, y, theta=np.array([0.5, 0.5]))
print('Con theta = [0.5, 0.5]\n Costo calculado = %.2f' % J)
# print('Valor de costo esperado (aproximadamente)  54.24')

J = calcularCosto(X, y, theta=np.array([0.6, 0.6]))
print('Con theta = [0.6, 0.6]\n Costo calculado = %.2f' % J)

J = calcularCosto(X, y, theta=np.array([0.7, 0.7]))
print('Con theta = [0.7, 0.7]\n Costo calculado = %.2f' % J)

J = calcularCosto(X, y, theta=np.array([0.8, 0.8]))
print('Con theta = [0.8, 0.8]\n Costo calculado = %.2f' % J)

J = calcularCosto(X, y, theta=np.array([0.75, 0.75]))
print('Con theta = [0.75, 0.75]\n Costo calculado = %.2f' % J)
# Out:
# Con theta = [0, 0]
#  Costo calculado = 276252.82
# Con theta = [0.5, 0.5]
#  Costo calculado = 270718.46
# Con theta = [0.6, 0.6]
#  Costo calculado = 269618.82
# Con theta = [0.7, 0.7]
#  Costo calculado = 268521.60
# Con theta = [0.8, 0.8]
#  Costo calculado = 267426.79
# Con theta = [0.75, 0.75]
#  Costo calculado = 267973.89

# %%
def gradientDescent(X, y, theta, alpha, num_iters):
        # Inicializa algunos valores importantes
    m = y.shape[0]  # numero de ejemplos de entrenamiento

    # hace una copia de theta, para evitar cambiar la matriz original,
    # ya que las matrices numpy se pasan por referencia a las funciones

    theta = theta.copy()

    J_history = [] # Lista que se utiliza para almacenar el costo en cada iteración

    for i in range(num_iters):
        theta = theta - (alpha / m) * (np.dot(X, theta) - y).dot(X)
        # save the cost J in every iteration
        J_history.append(calcularCosto(X, y, theta))

    return theta, J_history

# %%
# inicializa los parametros de ajuste
theta = np.zeros(2)

# configuraciones para el descenso por el gradiente
iterations = 500
alpha = 0.001

theta, J_history = gradientDescent(X ,y, theta, alpha, iterations)
print('Theta encontrada por descenso gradiente: {:.4f}, {:.4f}'.format(*theta))
print('Valores theta esperados (aproximadamente): [-3.6303, 1.1664]')
print(J_history)
# Out:
# Theta encontrada por descenso gradiente: -17.9923, 50.5975
# Valores theta esperados (aproximadamente): [-3.6303, 1.1664]
# ...

# %%
# grafica la linea de ajuste
""" plotData(X[:, 1], y)
pyplot.plot(X[:, 1], np.dot(X, theta), '-')
pyplot.legend(['Datos de entrenamiento', 'Regresión linear']); """


plotData(X[:, 1], y)
pyplot.plot(X[:, 1], np.dot(X, theta), '-')
pyplot.legend(['Datos de entrenamiento', 'Regresión linear'])

# %%
# Supongamos que quieres predecir el área para un radio promedio de 15 y 20

radio1 = 15
radio2 = 20

predict1 = np.dot([1, radio1], theta)  # vector [1, radio] para término independiente + radio
print(f'Para un radio promedio de {radio1}, se predice un área promedio de {predict1:.2f}')

predict2 = np.dot([1, radio2], theta)
print(f'Para un radio promedio de {radio2}, se predice un área promedio de {predict2:.2f}')
# Out:
# Para un radio promedio de 15, se predice un área promedio de 740.97
# Para un radio promedio de 20, se predice un área promedio de 993.96

# %%
pyplot.figure()
pyplot.plot(np.arange(len(J_history)), J_history, lw=2)
pyplot.xlabel('Iteraciones')
pyplot.ylabel('Costo J')
pyplot.title('Convergencia del costo')
pyplot.grid(True)
pyplot.show()
